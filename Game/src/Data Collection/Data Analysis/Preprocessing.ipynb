# %%
#import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading user dataset
user = pd.read_csv(r'C:\Users\anchi\Game_Recommendation\Game\data\steam_games.csv\user dataset.csv')
user
# Out:
#         151603712  The Elder Scrolls V Skyrim  purchase    1.0  0
# 0       151603712  The Elder Scrolls V Skyrim      play  273.0  0
# 1       151603712                   Fallout 4  purchase    1.0  0
# 2       151603712                   Fallout 4      play   87.0  0
# 3       151603712                       Spore  purchase    1.0  0
# 4       151603712                       Spore      play   14.9  0
# ...           ...                         ...       ...    ... ..
# 199994  128470551                 Titan Souls      play    1.5  0
# 199995  128470551  Grand Theft Auto Vice City  purchase    1.0  0
# 199996  128470551  Grand Theft Auto Vice City      play    1.5  0
# 199997  128470551                        RUSH  purchase    1.0  0
# 199998  128470551                        RUSH      play    1.4  0
#
# [199999 rows x 5 columns]

# %%
# Renaming columns and drop the last column
user.rename(columns = {'151603712':'user_id','1.0':'Value','The Elder Scrolls V Skyrim':'Game_Name'},inplace= True)
user.drop(columns = ['0'],inplace= True)
user
# Out:
#           user_id                   Game_Name  purchase  Value
# 0       151603712  The Elder Scrolls V Skyrim      play  273.0
# 1       151603712                   Fallout 4  purchase    1.0
# 2       151603712                   Fallout 4      play   87.0
# 3       151603712                       Spore  purchase    1.0
# 4       151603712                       Spore      play   14.9
# ...           ...                         ...       ...    ...
# 199994  128470551                 Titan Souls      play    1.5
# 199995  128470551  Grand Theft Auto Vice City  purchase    1.0
# 199996  128470551  Grand Theft Auto Vice City      play    1.5
# 199997  128470551                        RUSH  purchase    1.0
# 199998  128470551                        RUSH      play    1.4
#
# [199999 rows x 4 columns]

# %%
# Reading Game Dataset
steam_games = pd.read_csv(r'C:\Users\anchi\Game_Recommendation\Game\data\steam_games.csv\steam_games.csv')
steam_games
# Out:
#                                                      url types  \
# 0        https://store.steampowered.com/app/379720/DOOM/   app
# 1      https://store.steampowered.com/app/578080/PLAY...   app
# 2      https://store.steampowered.com/app/637090/BATT...   app
# 3        https://store.steampowered.com/app/221100/DayZ/   app
# 4      https://store.steampowered.com/app/8500/EVE_On...   app
# ...                                                  ...   ...
# 40828  https://store.steampowered.com/app/899836/Rock...   app
# 40829  https://store.steampowered.com/app/899832/Rock...   app
# 40830  https://store.steampowered.com/app/906840/Fant...   app
# 40831  https://store.steampowered.com/app/906635/Mega...   app
# 40832  https://store.steampowered.com/app/908000/Stor...   app
#
#                                                     name  \
# 0                                                   DOOM
# 1                          PLAYERUNKNOWN'S BATTLEGROUNDS
# ...

# %%
# Reading columns of both datasets

print('Steam Games Columns --->',steam_games.columns.to_list())
print('User dataset Columns ---->',user.columns.to_list())
# Out:
# Steam Games Columns ---> ['url', 'types', 'name', 'desc_snippet', 'recent_reviews', 'all_reviews', 'release_date', 'developer', 'publisher', 'popular_tags', 'game_details', 'languages', 'achievements', 'genre', 'game_description', 'mature_content', 'minimum_requirements', 'recommended_requirements', 'original_price', 'discount_price']
# User dataset Columns ----> ['user_id', 'Game_Name', 'purchase', 'Value']

# %% [markdown]
# Data Preprocessing

# %%
# Handling missing values
steam_games.isnull().sum()
# Out:
# url                             0
# types                           2
# name                           16
# desc_snippet                13221
# recent_reviews              38127
# all_reviews                 12363
# release_date                 3179
# developer                     343
# publisher                    5100
# popular_tags                 2945
# game_details                  520
# languages                      36
# achievements                28639
# genre                         438
# game_description             2913
# mature_content              37936
# minimum_requirements        19764
# recommended_requirements    19758
# original_price               5311
# discount_price              26290
# dtype: int64

# %%
user.isnull().sum()
# Out:
# user_id      0
# Game Name    0
# purchase     0
# Value        0
# dtype: int64

# %%
# shape of games dataset
print(steam_games.shape)
print(user.shape)
# Out:
# (40833, 20)
# (199999, 4)

# %%
# Numerical columns: Columns with int or float data types
numerical_columns = steam_games.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_columns = steam_games.select_dtypes(include=['object', 'category']).columns.tolist()

print("Numerical Columns:", numerical_columns)
print("Categorical Columns:", categorical_columns)
# Out:
# Numerical Columns: ['achievements']
# Categorical Columns: ['url', 'types', 'name', 'desc_snippet', 'recent_reviews', 'all_reviews', 'release_date', 'developer', 'publisher', 'popular_tags', 'game_details', 'languages', 'genre', 'game_description', 'mature_content', 'minimum_requirements', 'recommended_requirements', 'original_price', 'discount_price']

# %%
# Numerical columns
numerical_columns = ['achievements']
for col in numerical_columns:
    if steam_games[col].isnull().any():
        steam_games[col].fillna(steam_games[col].median(), inplace=True)

categorical_columns = ['url', 'types', 'name', 'desc_snippet', 'recent_reviews', 'all_reviews', 'release_date', 'developer', 'publisher', 'popular_tags', 'game_details', 'languages', 'genre', 'game_description', 'mature_content', 'minimum_requirements', 'recommended_requirements', 'original_price', 'discount_price']

for col in categorical_columns:
    if steam_games[col].isnull().any():
        mode_value = steam_games[col].mode()[0]  
        steam_games[col].fillna(mode_value, inplace=True)
        
print(steam_games.isnull().sum())
# Out:
# url                         0
# types                       0
# name                        0
# desc_snippet                0
# recent_reviews              0
# all_reviews                 0
# release_date                0
# developer                   0
# publisher                   0
# popular_tags                0
# game_details                0
# languages                   0
# achievements                0
# genre                       0
# game_description            0
# mature_content              0
# minimum_requirements        0
# recommended_requirements    0
# original_price              0
# discount_price              0
# dtype: int64

# %%
steam_games['types'].value_counts()
# Out:
# types
# app       38023
# bundle     2572
# sub         238
# Name: count, dtype: int64

# %%
# name
# developer
# recent reviews
# all reviews
# publisher
# popular _tags
# game_details
# language
# genre
# game_description
# mature content
# Game Name 
# Purchase
# Value

# %%
# Concatenation of DataFrame
combine_df = pd.concat([user,steam_games],axis=1)
combine_df.shape
# Out:
# (199999, 24)

# %%
combine_df.drop(['url','types','release_date','developer','publisher','minimum_requirements', 'recommended_requirements', 'original_price', 'discount_price','Value','user_id','desc_snippet'],axis =1, inplace= True)

# %%
combine_df.shape
# Out:
# (199999, 12)
